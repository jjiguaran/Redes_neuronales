# %%
# Este entorno de Python 3 es similar a Jupyter Notebook
# Viene con varias librerías instaladas. Para más információn podés consultar 
# la imagen de docker que utiliza (https://github.com/kaggle/docker-python)

import numpy as np 
import pandas as pd
import keras
import matplotlib.pyplot as plt
# %matplotlib inline

# Los archivos del zip "chest_xray.zip" están disponibles automáticamente en la 
# carpeta "/kaggle/input/aa2019unlp/chest_xray"
# (o "../input/aa2019unlp/chest_xray")
# Por ejemplo, el siguiente código imprime todos los archivos disponibles:
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Cualquier resultado que guarden en el directorio actual queda como un "output" en el workspace
# Out:
# Using TensorFlow backend.
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0375_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0374_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0301_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0364_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0311_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0303_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0327_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0273_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0336_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0368_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0351_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0352_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0316_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0320_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0312_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0261_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0257_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0346_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0292_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0328_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0340_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0275_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0266_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0372_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0339_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0330_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0363_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0333_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0358_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0380_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0357_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0384_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0366_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0377_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0291_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0262_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0329_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0383_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0318_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0298_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0279_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0341_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0294_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0271_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0367_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0321_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0310_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0359_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0274_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0313_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0347_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0270_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0293_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0259_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0356_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0308_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0278_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0287_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0297_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0302_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0335_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0258_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0382_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0267_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0299_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0373_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0263_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0326_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0325_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0337_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0269_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0324_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0295_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0348_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0365_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0370_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0315_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0283_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0280_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0304_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0323_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0343_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0350_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0285_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0322_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0349_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0379_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0260_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0360_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0361_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0355_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0362_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0289_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0338_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0342_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0286_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0371_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0378_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0305_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0345_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0332_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0272_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0288_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0344_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0309_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0265_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0268_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0354_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0277_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0300_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0282_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0307_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0284_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0314_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0317_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0264_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0369_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0290_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0319_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0381_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0276_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0281_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0376_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0306_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0353_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0331_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0296_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/normal/0334_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2944_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0143_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2964_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0188_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2963_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0190_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2910_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2929_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0148_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2909_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2953_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0160_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0132_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2966_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0144_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0161_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2965_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0167_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0171_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2968_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2957_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2915_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0136_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2960_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2912_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2943_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2916_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0172_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0159_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2908_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0158_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2921_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2951_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2933_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2958_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0162_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0156_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0185_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2917_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0165_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0138_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2918_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2932_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2950_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0191_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2923_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0176_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0174_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2970_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2962_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2949_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2936_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2954_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2947_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0130_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2935_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2959_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0137_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0129_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0169_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0184_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2911_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0183_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2941_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0168_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0182_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0134_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0135_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0153_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0149_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2938_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2937_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0146_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2913_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2920_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2940_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0157_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0152_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2967_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0177_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2956_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0187_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2948_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2919_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0189_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0150_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0186_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0141_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0180_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2928_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0166_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0170_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0154_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0151_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0179_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2934_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0140_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0133_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2927_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2924_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0139_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0178_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2952_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2925_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0175_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0128_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0147_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0173_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2942_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0163_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2914_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2971_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2946_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2969_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0142_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0181_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0131_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2931_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2945_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2955_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0145_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2922_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0164_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2961_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/0155_bacteria.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2939_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2930_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/val/pneumonia/2926_virus.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0654_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0441_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0679_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0809_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0586_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1491_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1487_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0458_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1057_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0959_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1189_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1528_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0708_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1044_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1126_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0829_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0812_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1070_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1390_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0871_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0522_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1160_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1378_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0431_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0553_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0616_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1298_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1245_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1346_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1028_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0753_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1561_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0519_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0665_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0975_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1497_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0730_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0786_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1049_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0862_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1233_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0473_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1165_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0964_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1223_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0611_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1368_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0538_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1259_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1032_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0513_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1443_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1402_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1460_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0990_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1136_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1041_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1215_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1250_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0672_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1364_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1196_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1375_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1283_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1135_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0399_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0934_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0590_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1492_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0699_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0800_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0716_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0461_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0873_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1399_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1540_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1351_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0957_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1252_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1269_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0818_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0576_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1238_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0477_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0687_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0997_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0981_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1466_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1157_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1325_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1362_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1112_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0827_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0863_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1567_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1207_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0532_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0702_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0733_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0973_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0535_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0666_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1009_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1305_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1490_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1572_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0521_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0860_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1059_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0649_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0681_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0811_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0443_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1204_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0670_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0436_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1175_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1144_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0936_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1042_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0856_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0736_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0739_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1562_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0710_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1577_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0525_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1354_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0644_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1006_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0798_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0520_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1338_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1558_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0612_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1297_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1441_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0659_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0595_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0766_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0878_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1051_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0615_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0965_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0445_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0712_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1031_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0737_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0405_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1515_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1445_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1181_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0703_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1203_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1242_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1127_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1079_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0400_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1295_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1263_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0419_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0678_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1463_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0962_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0924_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1254_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0925_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0718_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1481_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1084_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0401_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1054_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1475_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1246_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1500_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0619_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0488_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1564_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0779_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0526_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1382_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0432_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0720_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0755_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0974_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0891_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0807_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0740_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0935_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1170_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0456_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1253_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0918_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1418_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0943_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0391_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0667_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0813_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1401_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1064_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1530_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1420_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1376_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1182_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1495_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0605_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1053_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0455_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1125_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1012_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1036_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0476_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1496_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0457_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1504_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1555_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1526_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0756_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0623_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1096_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0554_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1038_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1015_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1473_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0653_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0841_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0475_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0759_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1192_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1248_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0760_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0628_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1128_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1485_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1282_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1509_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0837_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0442_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1520_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1313_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0987_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1524_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0744_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0866_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0517_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1046_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0539_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1582_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1542_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0852_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0484_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1289_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1383_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0822_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1260_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0778_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1294_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1476_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1180_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0881_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0993_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0714_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0945_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0592_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0804_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1302_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1541_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0884_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1519_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0637_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0663_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1140_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0481_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1518_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0418_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0536_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0986_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0534_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1066_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0421_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1191_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0816_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0427_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0996_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1538_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1231_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0793_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1569_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1471_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1422_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0966_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1239_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0819_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0923_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1428_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0709_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1149_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0564_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0784_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0723_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1557_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0706_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0982_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0599_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0802_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0635_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0892_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1413_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0722_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1198_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1142_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0478_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0598_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0593_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0621_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0942_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1439_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0747_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1498_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1350_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1429_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1414_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0850_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0977_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1389_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1465_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1077_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1249_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1437_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0941_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0398_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0437_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1546_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1039_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1513_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1317_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1380_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1580_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0894_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0464_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1163_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1545_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0909_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0697_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1033_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1131_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0626_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1278_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0471_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0998_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0638_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0895_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0389_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1087_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1267_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0808_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0602_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0629_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0454_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0541_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0662_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1072_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0523_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0940_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1168_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0968_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1334_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0810_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0429_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0507_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0584_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1256_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1347_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0617_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1264_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0453_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0643_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0764_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1162_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0415_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0978_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1359_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0396_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1037_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0963_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1011_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1514_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1521_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0694_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1173_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0543_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0848_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0646_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1339_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0762_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0743_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1522_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0888_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1193_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0633_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1411_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1527_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1107_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1247_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1332_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1348_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1055_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0426_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1200_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1398_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1134_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0887_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1279_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1409_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0634_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1132_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0435_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1556_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1576_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1071_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0944_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0914_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1169_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0828_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1392_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0609_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0578_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1284_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0449_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0776_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0773_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1040_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0958_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1488_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1474_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1416_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0967_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0571_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0938_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1197_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0794_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1453_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1187_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0752_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0880_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1105_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1000_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0992_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0844_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0511_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0550_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1322_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1179_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0497_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1292_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1152_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1139_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0407_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0485_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0689_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0560_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1367_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1102_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1081_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1464_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0896_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0761_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1314_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0726_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0969_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0392_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0897_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0777_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1069_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1099_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1374_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0581_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1373_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1340_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0921_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1405_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/0867_normal.jpg
# /kaggle/input/aa2019unlp/chest_xray/train/normal/1114_normal.jpg
# ...
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0244.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0142.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0380.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0451.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0472.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0222.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0049.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0346.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0009.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0459.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0264.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0058.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0432.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0036.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0377.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0286.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0426.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0305.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0199.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0044.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0173.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0325.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0230.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0298.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0483.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0078.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0399.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0276.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0457.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0185.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0144.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0245.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0136.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0256.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0452.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0296.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0433.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0171.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0482.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0295.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0109.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0032.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0280.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0145.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0471.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0349.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0407.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0379.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0339.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0387.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0214.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0020.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0461.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0511.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0010.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0335.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0061.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0253.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0224.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0312.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0448.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0259.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0424.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0052.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0179.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0087.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0246.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0413.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0027.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0495.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0423.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0287.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0038.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0306.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0330.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0138.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0366.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0453.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0428.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0188.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0404.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0023.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0143.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0314.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0301.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0092.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0506.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0319.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0034.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0146.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0436.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0106.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0443.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0303.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0487.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0122.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0489.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0104.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0351.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0278.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0110.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0055.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0347.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0118.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0162.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0137.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0204.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0208.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0449.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0067.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0365.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0050.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0357.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0362.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0006.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0447.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0002.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0014.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0275.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0315.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0391.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0201.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0485.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0169.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0053.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0478.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0334.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0218.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0454.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0226.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0159.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0364.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0481.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0135.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0180.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0177.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0157.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0057.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0232.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0313.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0383.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0075.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0120.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0307.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0309.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0176.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0028.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0368.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0066.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0329.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0031.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0416.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0435.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0281.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0008.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0186.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0490.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0080.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0018.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0011.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0267.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0026.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0133.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0129.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0077.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0316.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0054.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0164.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0284.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0318.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0017.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0458.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0344.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0271.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0125.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0105.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0470.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0308.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0210.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0166.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0097.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0191.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0198.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0324.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0072.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0239.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0382.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0285.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0254.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0460.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0035.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0484.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0160.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0442.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0102.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0455.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0182.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0376.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0113.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0084.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0235.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0074.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0337.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0412.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0085.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0148.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0195.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0124.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0390.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0434.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0294.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0360.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0393.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0340.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0288.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0392.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0317.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0172.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0367.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0096.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0465.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0158.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0353.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0068.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0510.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0270.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0345.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0350.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0252.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0127.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0163.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0384.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0300.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0012.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0241.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0282.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0134.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0491.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0394.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0437.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0396.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0293.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0216.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0438.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0152.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0005.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0223.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0410.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0117.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0328.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0033.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0076.jpg
# /kaggle/input/aa2019unlp/chest_xray/test/unknown/test_0059.jpg

# %%
from keras.preprocessing.image import load_img
dataset_folderpath="/kaggle/input/aa2019unlp/chest_xray"
print("Hay 3 directorios con los tres subconjuntos de datos: ",os.listdir(dataset_folderpath))
print("La carpeta de cada subconjunto tiene dos subcarpetas: NORMAL y PNEUMONIA")

train_folderpath = os.path.join(dataset_folderpath,"train")
val_folderpath = os.path.join(dataset_folderpath,"val")
test_folderpath = os.path.join(dataset_folderpath,"test")

img_name = '1500_normal.jpg'
image_path= f'normal/{img_name}'
img_normal = load_img(os.path.join(train_folderpath,image_path))

print(f"Las imágenes tienen tamaño: {img_normal.size}")

plt.imshow(img_normal)
plt.title("Normal")
plt.show()

img_name = '0864_bacteria.jpg'
image_path= f'pneumonia/{img_name}'
img_bacteria = load_img(os.path.join(train_folderpath,image_path))
plt.imshow(img_bacteria)
plt.title("Neumonía bacteriana")
plt.show()


img_name = '3799_virus.jpg'
image_path= f'pneumonia/{img_name}'
img_virus = load_img(os.path.join(train_folderpath,image_path))
plt.imshow(img_virus)
plt.title("Neumonía virósica")
plt.show()
# Out:
# Hay 3 directorios con los tres subconjuntos de datos:  ['val', 'train', 'test']
# La carpeta de cada subconjunto tiene dos subcarpetas: NORMAL y PNEUMONIA
# Las imágenes tienen tamaño: (600, 600)

# %%
from keras.preprocessing.image import ImageDataGenerator


# Tamaño objetivo para escalar las imágenes. 
h,w,c = 32, 32, 3

batch_size=32

# Preprocesamiento de cada subconjunto
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    )

val_datagen = ImageDataGenerator(
    rescale=1. / 255,
    )

test_datagen = ImageDataGenerator(
    rescale=1. / 255,
    )

# Generadores de los subconjuntos. Reciben un directorio, y 
# cada carpeta del directorio se interpreta como una clase distinta.
# En este caso como cada directorio tiene 2 subdirectorios, NORMAL y PNEUMONIA,
# por ende, habrá dos clases.
# Además, al especificar el "class_mode" como binary, la salida se codifica como un solo valor
# (0 o 1), y no como un vector one-hot de dos elementos.

train_generator = train_datagen.flow_from_directory(
    train_folderpath, # directorio de donde cargar las imagenes (train)
    target_size=(h,w),
    batch_size=batch_size,
    class_mode='binary')

val_generator = val_datagen.flow_from_directory(
    val_folderpath, # directorio de donde cargar las imagenes (val)
    target_size=(h,w),
    batch_size=batch_size,
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    test_folderpath,# directorio de donde cargar las imagenes (test)
    target_size=(h,w),
    batch_size=batch_size,
    class_mode=None, # IMPORTANTE ya que los ej de test no tienen clase
    shuffle=False # IMPORTANTE ya que nos importa el orden para el archivo de submission
    )


n_train=train_generator.samples
n_val=val_generator.samples
n_test=test_generator.samples
n_clases=train_generator.num_classes
print(f"Los conjuntos de train, val y test tienen {n_train}, {n_val} y {n_test} ejemplos respectivamente.")
print(f"Los conjuntos de datos tienen {n_clases} clases.")
# Out:
# Found 5088 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.
# Found 512 images belonging to 1 classes.
# Los conjuntos de train, val y test tienen 5088, 256 y 512 ejemplos respectivamente.
# Los conjuntos de datos tienen 2 clases.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

model = Sequential()
model.add(Flatten(input_shape=(h,w,c)))
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                196672
# _________________________________________________________________
# activation_1 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 196,737
# Trainable params: 196,737
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras import backend as K
# Definición de las métricas F1, recall y precision utilizando Keras.

def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
val_steps=max(1,n_val // batch_size)
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy",f1_m,precision_m, recall_m])
model.fit_generator(train_generator,
                    steps_per_epoch=n_train // batch_size,
                    epochs=2,
                    validation_data=val_generator,
                    validation_steps=val_steps
                    )
# Out:
# Epoch 1/2
# 159/159 [==============================] - 23s 144ms/step - loss: 0.3851 - accuracy: 0.8341 - f1_m: 0.8904 - precision_m: 0.8424 - recall_m: 0.9588 - val_loss: 0.2602 - val_accuracy: 0.8789 - val_f1_m: 0.8824 - val_precision_m: 0.8236 - val_recall_m: 0.9596
# Epoch 2/2
# 159/159 [==============================] - 15s 95ms/step - loss: 0.2335 - accuracy: 0.9035 - f1_m: 0.9370 - precision_m: 0.9232 - recall_m: 0.9566 - val_loss: 0.1326 - val_accuracy: 0.9180 - val_f1_m: 0.9194 - val_precision_m: 0.8911 - val_recall_m: 0.9545

# %%
#Evaluar el accuracy del modelo en el conjunto entero de entrenamiento
print("*********** Conjunto de entrenamiento ***********")
train_generator.reset()
asd = model.predict_generator(train_generator,steps=n_train // batch_size)
scores = model.evaluate_generator(train_generator,steps=n_train // batch_size)
for metric,score in zip(model.metrics_names,scores):
    print(f"{metric}: {score:.2f}")

print()
# Evaluar el accuracy del modelo en el conjunto entero de validación
print("*********** Conjunto de validación ***********")
val_generator.reset()
asd = model.predict_generator(val_generator,steps=n_val // batch_size)
scores = model.evaluate_generator(val_generator,steps=n_val // batch_size)
for metric,score in zip(model.metrics_names,scores):
    print(f"{metric}: {score:.2f}")
# Out:
# *********** Conjunto de entrenamiento ***********
# loss: 0.11
# accuracy: 0.94
# f1_m: 0.96
# precision_m: 0.95
# recall_m: 0.97
#
# *********** Conjunto de validación ***********
# loss: 0.13
# accuracy: 0.92
# f1_m: 0.92
# precision_m: 0.89
# recall_m: 0.95

# %%
# predecir sobre el conjunto de test y generar el csv resultante
y_prob = model.predict_generator(test_generator,steps=n_test // batch_size)
# Establecer un umbral
treshold=0.5
# Convertir probabilidades a etiquetas con el umbral
y_pred = (y_prob[:,0]>0.5).astype(int)
# quitar el nombre de la carpeta del nombre de archivo
filenames=[ os.path.basename(f) for f in test_generator.filenames]
# igual cant de archivos que de predicciones
assert(len(y_pred)==len(filenames))

# Generar CSV con las predicciones
import csv
with open('solutions.csv', mode='w') as f:
    writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    writer.writerow(['Id','Expected'])
    print("Id, Expected")
    for f,y in zip(filenames,y_pred):
        print(f"{f}, {str(y)}")
        writer.writerow([f,str(y)])
# Out:
# Id, Expected
# test_0000.jpg, 1
# test_0001.jpg, 0
# test_0002.jpg, 0
# test_0003.jpg, 1
# test_0004.jpg, 0
# test_0005.jpg, 1
# test_0006.jpg, 1
# test_0007.jpg, 0
# test_0008.jpg, 0
# test_0009.jpg, 1
# test_0010.jpg, 1
# test_0011.jpg, 0
# test_0012.jpg, 1
# test_0013.jpg, 1
# test_0014.jpg, 0
# test_0015.jpg, 1
# test_0016.jpg, 0
# test_0017.jpg, 0
# test_0018.jpg, 0
# test_0019.jpg, 1
# test_0020.jpg, 1
# test_0021.jpg, 0
# test_0022.jpg, 1
# test_0023.jpg, 0
# test_0024.jpg, 0
# test_0025.jpg, 1
# test_0026.jpg, 0
# test_0027.jpg, 1
# test_0028.jpg, 0
# test_0029.jpg, 1
# test_0030.jpg, 1
# test_0031.jpg, 0
# test_0032.jpg, 1
# test_0033.jpg, 1
# test_0034.jpg, 1
# test_0035.jpg, 1
# test_0036.jpg, 1
# test_0037.jpg, 1
# test_0038.jpg, 1
# test_0039.jpg, 1
# test_0040.jpg, 1
# test_0041.jpg, 1
# test_0042.jpg, 1
# test_0043.jpg, 1
# test_0044.jpg, 0
# test_0045.jpg, 1
# test_0046.jpg, 1
# test_0047.jpg, 1
# test_0048.jpg, 0
# test_0049.jpg, 1
# test_0050.jpg, 1
# test_0051.jpg, 1
# test_0052.jpg, 1
# test_0053.jpg, 1
# test_0054.jpg, 0
# test_0055.jpg, 1
# test_0056.jpg, 0
# test_0057.jpg, 0
# test_0058.jpg, 1
# test_0059.jpg, 0
# test_0060.jpg, 1
# test_0061.jpg, 1
# test_0062.jpg, 1
# test_0063.jpg, 1
# test_0064.jpg, 1
# test_0065.jpg, 0
# test_0066.jpg, 1
# test_0067.jpg, 0
# test_0068.jpg, 1
# test_0069.jpg, 1
# test_0070.jpg, 1
# test_0071.jpg, 1
# test_0072.jpg, 1
# test_0073.jpg, 1
# test_0074.jpg, 0
# test_0075.jpg, 1
# test_0076.jpg, 1
# test_0077.jpg, 1
# test_0078.jpg, 1
# test_0079.jpg, 0
# test_0080.jpg, 0
# test_0081.jpg, 1
# test_0082.jpg, 1
# test_0083.jpg, 0
# test_0084.jpg, 1
# test_0085.jpg, 0
# test_0086.jpg, 0
# test_0087.jpg, 1
# test_0088.jpg, 0
# test_0089.jpg, 0
# test_0090.jpg, 1
# test_0091.jpg, 1
# test_0092.jpg, 1
# test_0093.jpg, 0
# test_0094.jpg, 1
# test_0095.jpg, 0
# test_0096.jpg, 1
# test_0097.jpg, 1
# test_0098.jpg, 1
# test_0099.jpg, 1
# test_0100.jpg, 0
# test_0101.jpg, 0
# test_0102.jpg, 0
# test_0103.jpg, 0
# test_0104.jpg, 0
# test_0105.jpg, 1
# test_0106.jpg, 0
# test_0107.jpg, 0
# test_0108.jpg, 1
# test_0109.jpg, 0
# test_0110.jpg, 0
# test_0111.jpg, 0
# test_0112.jpg, 1
# test_0113.jpg, 1
# test_0114.jpg, 1
# test_0115.jpg, 1
# test_0116.jpg, 0
# test_0117.jpg, 1
# test_0118.jpg, 1
# test_0119.jpg, 1
# test_0120.jpg, 0
# test_0121.jpg, 1
# test_0122.jpg, 0
# test_0123.jpg, 0
# test_0124.jpg, 1
# test_0125.jpg, 0
# test_0126.jpg, 1
# test_0127.jpg, 0
# test_0128.jpg, 0
# test_0129.jpg, 0
# test_0130.jpg, 1
# test_0131.jpg, 1
# test_0132.jpg, 1
# test_0133.jpg, 0
# test_0134.jpg, 0
# test_0135.jpg, 1
# test_0136.jpg, 1
# test_0137.jpg, 1
# test_0138.jpg, 0
# test_0139.jpg, 0
# test_0140.jpg, 0
# test_0141.jpg, 1
# test_0142.jpg, 0
# test_0143.jpg, 1
# test_0144.jpg, 0
# test_0145.jpg, 1
# test_0146.jpg, 1
# test_0147.jpg, 1
# test_0148.jpg, 1
# test_0149.jpg, 0
# test_0150.jpg, 0
# test_0151.jpg, 1
# test_0152.jpg, 1
# test_0153.jpg, 0
# test_0154.jpg, 1
# test_0155.jpg, 1
# test_0156.jpg, 1
# test_0157.jpg, 0
# test_0158.jpg, 1
# test_0159.jpg, 1
# test_0160.jpg, 1
# test_0161.jpg, 1
# test_0162.jpg, 0
# test_0163.jpg, 1
# test_0164.jpg, 1
# test_0165.jpg, 1
# test_0166.jpg, 1
# test_0167.jpg, 1
# test_0168.jpg, 1
# test_0169.jpg, 1
# test_0170.jpg, 1
# test_0171.jpg, 1
# test_0172.jpg, 0
# test_0173.jpg, 0
# test_0174.jpg, 1
# test_0175.jpg, 0
# test_0176.jpg, 0
# test_0177.jpg, 1
# test_0178.jpg, 1
# test_0179.jpg, 1
# test_0180.jpg, 1
# test_0181.jpg, 1
# test_0182.jpg, 1
# test_0183.jpg, 1
# test_0184.jpg, 0
# test_0185.jpg, 0
# test_0186.jpg, 1
# test_0187.jpg, 0
# test_0188.jpg, 1
# test_0189.jpg, 0
# test_0190.jpg, 0
# test_0191.jpg, 1
# test_0192.jpg, 1
# test_0193.jpg, 1
# test_0194.jpg, 1
# test_0195.jpg, 1
# test_0196.jpg, 1
# test_0197.jpg, 0
# test_0198.jpg, 1
# test_0199.jpg, 0
# test_0200.jpg, 1
# test_0201.jpg, 1
# test_0202.jpg, 1
# test_0203.jpg, 1
# test_0204.jpg, 1
# test_0205.jpg, 0
# test_0206.jpg, 1
# test_0207.jpg, 1
# test_0208.jpg, 0
# test_0209.jpg, 1
# test_0210.jpg, 1
# test_0211.jpg, 1
# test_0212.jpg, 1
# test_0213.jpg, 1
# test_0214.jpg, 1
# test_0215.jpg, 1
# test_0216.jpg, 1
# test_0217.jpg, 0
# test_0218.jpg, 1
# test_0219.jpg, 1
# test_0220.jpg, 1
# test_0221.jpg, 1
# test_0222.jpg, 1
# test_0223.jpg, 0
# test_0224.jpg, 1
# test_0225.jpg, 1
# test_0226.jpg, 1
# test_0227.jpg, 1
# test_0228.jpg, 1
# test_0229.jpg, 1
# test_0230.jpg, 0
# test_0231.jpg, 1
# test_0232.jpg, 1
# test_0233.jpg, 1
# test_0234.jpg, 1
# test_0235.jpg, 1
# test_0236.jpg, 1
# test_0237.jpg, 1
# test_0238.jpg, 1
# test_0239.jpg, 0
# test_0240.jpg, 0
# test_0241.jpg, 0
# test_0242.jpg, 1
# test_0243.jpg, 1
# test_0244.jpg, 1
# test_0245.jpg, 1
# test_0246.jpg, 1
# test_0247.jpg, 1
# test_0248.jpg, 1
# test_0249.jpg, 1
# test_0250.jpg, 0
# test_0251.jpg, 1
# test_0252.jpg, 1
# test_0253.jpg, 0
# test_0254.jpg, 1
# test_0255.jpg, 0
# test_0256.jpg, 1
# test_0257.jpg, 0
# test_0258.jpg, 0
# test_0259.jpg, 1
# test_0260.jpg, 0
# test_0261.jpg, 0
# test_0262.jpg, 0
# test_0263.jpg, 0
# test_0264.jpg, 1
# test_0265.jpg, 1
# test_0266.jpg, 1
# test_0267.jpg, 1
# test_0268.jpg, 1
# test_0269.jpg, 1
# test_0270.jpg, 0
# test_0271.jpg, 1
# test_0272.jpg, 1
# test_0273.jpg, 1
# test_0274.jpg, 1
# test_0275.jpg, 0
# test_0276.jpg, 0
# test_0277.jpg, 1
# test_0278.jpg, 0
# test_0279.jpg, 1
# test_0280.jpg, 0
# test_0281.jpg, 1
# test_0282.jpg, 1
# test_0283.jpg, 1
# test_0284.jpg, 1
# test_0285.jpg, 0
# test_0286.jpg, 0
# test_0287.jpg, 1
# test_0288.jpg, 1
# test_0289.jpg, 1
# test_0290.jpg, 1
# test_0291.jpg, 1
# test_0292.jpg, 1
# test_0293.jpg, 1
# test_0294.jpg, 1
# test_0295.jpg, 1
# test_0296.jpg, 1
# test_0297.jpg, 0
# test_0298.jpg, 1
# test_0299.jpg, 0
# test_0300.jpg, 1
# test_0301.jpg, 1
# test_0302.jpg, 1
# test_0303.jpg, 1
# test_0304.jpg, 1
# test_0305.jpg, 1
# test_0306.jpg, 0
# test_0307.jpg, 0
# test_0308.jpg, 1
# test_0309.jpg, 0
# test_0310.jpg, 1
# test_0311.jpg, 0
# test_0312.jpg, 1
# test_0313.jpg, 0
# test_0314.jpg, 1
# test_0315.jpg, 1
# test_0316.jpg, 1
# test_0317.jpg, 1
# test_0318.jpg, 1
# test_0319.jpg, 1
# test_0320.jpg, 0
# test_0321.jpg, 1
# test_0322.jpg, 0
# test_0323.jpg, 1
# test_0324.jpg, 1
# test_0325.jpg, 1
# test_0326.jpg, 1
# test_0327.jpg, 1
# test_0328.jpg, 1
# test_0329.jpg, 1
# test_0330.jpg, 0
# test_0331.jpg, 1
# test_0332.jpg, 1
# test_0333.jpg, 0
# test_0334.jpg, 1
# test_0335.jpg, 0
# test_0336.jpg, 0
# test_0337.jpg, 1
# test_0338.jpg, 1
# test_0339.jpg, 0
# test_0340.jpg, 1
# test_0341.jpg, 0
# test_0342.jpg, 0
# test_0343.jpg, 1
# test_0344.jpg, 1
# test_0345.jpg, 1
# test_0346.jpg, 1
# test_0347.jpg, 1
# test_0348.jpg, 1
# test_0349.jpg, 0
# test_0350.jpg, 1
# test_0351.jpg, 0
# test_0352.jpg, 1
# test_0353.jpg, 1
# test_0354.jpg, 1
# test_0355.jpg, 1
# test_0356.jpg, 0
# test_0357.jpg, 0
# test_0358.jpg, 0
# test_0359.jpg, 0
# test_0360.jpg, 0
# test_0361.jpg, 1
# test_0362.jpg, 0
# test_0363.jpg, 0
# test_0364.jpg, 0
# test_0365.jpg, 1
# test_0366.jpg, 1
# test_0367.jpg, 0
# test_0368.jpg, 1
# test_0369.jpg, 0
# test_0370.jpg, 1
# test_0371.jpg, 1
# test_0372.jpg, 0
# test_0373.jpg, 0
# test_0374.jpg, 1
# test_0375.jpg, 1
# test_0376.jpg, 1
# test_0377.jpg, 1
# test_0378.jpg, 1
# test_0379.jpg, 1
# test_0380.jpg, 1
# test_0381.jpg, 1
# test_0382.jpg, 1
# test_0383.jpg, 1
# test_0384.jpg, 0
# test_0385.jpg, 1
# test_0386.jpg, 1
# test_0387.jpg, 1
# test_0388.jpg, 1
# test_0389.jpg, 0
# test_0390.jpg, 1
# test_0391.jpg, 1
# test_0392.jpg, 1
# test_0393.jpg, 1
# test_0394.jpg, 0
# test_0395.jpg, 1
# test_0396.jpg, 1
# test_0397.jpg, 0
# test_0398.jpg, 1
# test_0399.jpg, 1
# test_0400.jpg, 1
# test_0401.jpg, 0
# test_0402.jpg, 1
# test_0403.jpg, 0
# test_0404.jpg, 1
# test_0405.jpg, 0
# test_0406.jpg, 1
# test_0407.jpg, 0
# test_0408.jpg, 0
# test_0409.jpg, 1
# test_0410.jpg, 1
# test_0411.jpg, 0
# test_0412.jpg, 1
# test_0413.jpg, 1
# test_0414.jpg, 1
# test_0415.jpg, 0
# test_0416.jpg, 0
# test_0417.jpg, 0
# test_0418.jpg, 0
# test_0419.jpg, 1
# test_0420.jpg, 0
# test_0421.jpg, 1
# test_0422.jpg, 0
# test_0423.jpg, 0
# test_0424.jpg, 1
# test_0425.jpg, 1
# test_0426.jpg, 1
# test_0427.jpg, 1
# test_0428.jpg, 1
# test_0429.jpg, 0
# test_0430.jpg, 1
# test_0431.jpg, 1
# test_0432.jpg, 0
# test_0433.jpg, 1
# test_0434.jpg, 1
# test_0435.jpg, 0
# test_0436.jpg, 0
# test_0437.jpg, 0
# test_0438.jpg, 0
# test_0439.jpg, 1
# test_0440.jpg, 0
# test_0441.jpg, 1
# test_0442.jpg, 0
# test_0443.jpg, 1
# test_0444.jpg, 1
# test_0445.jpg, 0
# test_0446.jpg, 1
# test_0447.jpg, 0
# test_0448.jpg, 1
# test_0449.jpg, 0
# test_0450.jpg, 0
# test_0451.jpg, 0
# test_0452.jpg, 0
# test_0453.jpg, 1
# test_0454.jpg, 1
# test_0455.jpg, 1
# test_0456.jpg, 1
# test_0457.jpg, 1
# test_0458.jpg, 1
# test_0459.jpg, 0
# test_0460.jpg, 1
# test_0461.jpg, 1
# test_0462.jpg, 0
# test_0463.jpg, 1
# test_0464.jpg, 1
# test_0465.jpg, 1
# test_0466.jpg, 1
# test_0467.jpg, 1
# test_0468.jpg, 1
# test_0469.jpg, 1
# test_0470.jpg, 0
# test_0471.jpg, 1
# test_0472.jpg, 1
# test_0473.jpg, 1
# test_0474.jpg, 1
# test_0475.jpg, 1
# test_0476.jpg, 0
# test_0477.jpg, 1
# test_0478.jpg, 0
# test_0479.jpg, 1
# test_0480.jpg, 0
# test_0481.jpg, 1
# test_0482.jpg, 0
# test_0483.jpg, 0
# test_0484.jpg, 1
# test_0485.jpg, 1
# test_0486.jpg, 1
# test_0487.jpg, 0
# test_0488.jpg, 1
# test_0489.jpg, 1
# test_0490.jpg, 1
# test_0491.jpg, 0
# test_0492.jpg, 1
# test_0493.jpg, 1
# test_0494.jpg, 0
# test_0495.jpg, 1
# test_0496.jpg, 1
# test_0497.jpg, 0
# test_0498.jpg, 0
# test_0499.jpg, 1
# test_0500.jpg, 1
# test_0501.jpg, 1
# test_0502.jpg, 0
# test_0503.jpg, 1
# test_0504.jpg, 1
# test_0505.jpg, 0
# test_0506.jpg, 1
# test_0507.jpg, 1
# test_0508.jpg, 1
# test_0509.jpg, 0
# test_0510.jpg, 0
# test_0511.jpg, 1
