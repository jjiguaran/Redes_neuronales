# %% [markdown]
# Del ejercicio anterior tome los pesos finales resultado de algún entrenamiento de cualquiera de las imágenes (w_final, b_final). Invierta las clases de los datos, es decir los datos de la clase 0, ahora serán de la clase 1 y los datos de la clase 1 ahora serán los de la clase 0.
# T2 = abs(T-1)
# Entrene un nuevo Adaline con la misma imagen (con las clases invertidas) y los pesos resultado del entrenamiento anterior.
# train_con_pesos(P, T2, alfa, max_ite, cota, funcion, True, W_final, b_final)

# %%
import numpy as np
import pandas as pd

from sklearn import preprocessing
#import matplotlib.pyplot as plt
from ImagenPuntosMPL import AbrirImagen
from adaline import train_con_pesos, plot
from adaline import train, plot

# %%
file_path =  "../Practica 1/Imágenes/Imagen 6.bmp"

X = AbrirImagen(file_path)
df_org = pd.DataFrame(X)
df_org.columns = ['x', 'y', 'label']

# %%
file_path =  "../Practica 1/Imágenes/Imagen 6.bmp"

X = AbrirImagen(file_path)
df_org = pd.DataFrame({'x': X[:, 0], 'y': X[:, 1], 'label': X[:, 2]})

# %%
x = df_org[['x','y']].values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)

df = pd.DataFrame(x_scaled)
df['label'] = df_org['label']
df.columns = df_org.columns
# Out:
# C:\Users\dalessam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
P = df[['x','y']].values
T = df[['label']].values

alfa = 0.1
max_ite = 30
cota = 0.00001

W_final = np.array([[0.05554797, -0.18818366]])
b_final = np.array([0.08768646])

funcion = 'logsig'

T2 = abs(T-1)

train_con_pesos(P, T2, alfa, max_ite, cota, funcion, True, W_final, b_final)
# Out:
# 1 [0.15381596]
# 2 [0.13080599]
# 3 [0.11436441]
# 4 [0.10244207]
# 5 [0.09361067]
# 6 [0.08686302]
# 7 [0.08154885]
# 8 [0.07724897]
# 9 [0.07368743]
# 10 [0.07067789]
# 11 [0.06809125]
# 12 [0.06583583]
# 13 [0.06384493]
# 14 [0.06206902]
# 15 [0.06047053]
# 16 [0.05902047]
# 17 [0.05769612]
# 18 [0.05647937]
# 19 [0.05535563]
# 20 [0.05431297]
# 21 [0.05334156]
# 22 [0.05243318]
# 23 [0.05158094]
# 24 [0.05077897]
# 25 [0.05002227]
# 26 [0.04930651]
# 27 [0.04862795]
# 28 [0.04798335]
# 29 [0.04736982]
# 30 [0.04678486]
# (array([[-5.82179563, -4.6585727 ]]),
#  array([3.26284384]),
#  30,
#  array([0.04678486]))

# %%
W
# Out:
# array([[-5.89851487, -4.55501812]])

# %% [markdown]
# a) ¿Qué observa durante el entrenamiento?
# b) ¿Cómo puede explicar ese fenómeno?

# %% [markdown]
# Siempre daba igual, no se movía mucho. Siempre trata de converger al mismo plano. La superficie del error es un paraboloide así que hay 1 mínimo si se usa 1 sola neurona. Si hubiera más podría haber mínimos locales.

# %% [markdown]
# c) Entrene un nuevo Adaline con el dataset con las clases invertidas utilizado en el ensayo anterior, pero usando una inicialización de pesos al azar. ¿Qué relación encuentra entre los pesos finales del entrenamiento original (w_final, b_final) y los obtenidos en este ensayo?

# %%
alfa = 0.1
max_ite = 30
cota = 0.00001

(W, b, ite, error_prom) = train(P, T2, alfa, max_ite, cota, funcion, True)
# Out:
# 1 [0.17345173]
# 2 [0.12960399]
# 3 [0.11285567]
# 4 [0.10115259]
# 5 [0.09250517]
# 6 [0.08589984]
# 7 [0.08069725]
# 8 [0.07648657]
# 9 [0.0729977]
# 10 [0.07004837]
# 11 [0.06751239]
# 12 [0.06530016]
# 13 [0.06334654]
# 14 [0.06160311]
# 15 [0.06003321]
# 16 [0.05860852]
# 17 [0.05730684]
# 18 [0.05611049]
# 19 [0.05500521]
# 20 [0.05397935]
# 21 [0.05302328]
# 22 [0.052129]
# 23 [0.05128974]
# 24 [0.05049978]
# 25 [0.04975421]
# 26 [0.04904882]
# 27 [0.04837994]
# 28 [0.04774439]
# 29 [0.04713935]
# 30 [0.04656236]

# %%
W
# Out:
# array([[-5.90441025, -4.60083685]])

# %% [markdown]
# Se llega casi al mismo resultado
